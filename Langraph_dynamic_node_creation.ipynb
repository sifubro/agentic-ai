# %%
# !pip install langgraph

# %%
# !pip install langchain

# %%
from langgraph.graph import add_node, add_edge
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from langgraph.graph import add_node, add_edge
#
# ImportError: cannot import name 'add_node' from 'langgraph.graph' (C:\Users\SiFuBrO\anaconda3\envs\torch\Lib\site-packages\langgraph\graph\__init__.py)
